# %%
import matplotlib.path as mpath
import matplotlib.patches as mpatches
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Exemplos basicos de como plotar utilizando o matplotlib:

# %%
#Primeiro iremos definir nossas variaveis:
x = [0,2,4,6,8,10]
y = [0.045,0.2,0.0005,0.093,0.00001,0.24]
plt.plot(x,y)

# %% [markdown]
# fig, ax = plt.subplots()
#
# Path = mpath.Path
# path_data = [
#     (Path.MOVETO, (1.58, -2.57)),
#     (Path.CURVE4, (0.35, -1.1)),
#     (Path.CURVE4, (-1.75, 2.0)),
#     (Path.CURVE4, (0.375, 2.0)),
#     (Path.LINETO, (0.85, 1.15)),
#     (Path.CURVE4, (2.2, 3.2)),
#     (Path.CURVE4, (3, 0.05)),
#     (Path.CURVE4, (2.0, -0.5)),
#     (Path.CLOSEPOLY, (1.58, -2.57)),
#     ]
# codes, verts = zip(*path_data)
# path = mpath.Path(verts, codes)
# patch = mpatches.PathPatch(path, facecolor='r', alpha=0.5)
# ax.add_patch(patch)
#
# # plot control points and connecting lines
# x, y = zip(*path.vertices)
# line, = ax.plot(x, y, 'go-')
#
# ax.grid()
# ax.axis('equal')

# %%
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)

fig, ax = plt.subplots()
ax.plot(t, s)

ax.set(xlabel='Tempo (s)', ylabel='Voltagem (mV)',
       title='Voltagem X Tempo')
ax.grid()

fig.savefig("test.png")

# %% [markdown]
# # Exemplos de como fazer gráfico no python

# %%
# Usando o comando figure e subplot do matplotlib

#Primeiro iremos definir nossas variaveis:
t = np.arange(0.0, 2.0, 0.01)
s1 = np.sin(2*np.pi*t)
s2 = np.cos(4*np.pi*t)
#comando que define o tamanha do gráfico plt.rcParams['figure.figsize'] = (largura,comprimento) 
plt.rcParams['figure.figsize'] = (20,10)

# %%
#Agora iremos plotar 4 graficos 
plt.figure() # comando de entrada 
plt.subplot(2,2,1) #subplot(numero de linhas , numero de colunas , posição do plot) 
plt.plot(t, s1) 
plt.subplot(2,2,2)
plt.plot(t, 2*s2)
plt.subplot(2,2,3)
plt.plot(t,4*s2)
plt.subplot(2,2,4)
plt.plot(t,10*s1)

# %%
# usaremos os mesmo comando acima mas iremos plotar todos os graficos em um só , repetindo a posição nos quatro casos 
#usaremos a posição 1 só por convenção 
plt.figure() # comando de entrada 
plt.subplot(2,2,1) #subplot(numero de linhas , numero de colunas , posição do plot) 
plt.plot(t, 5*s1) 
plt.subplot(2,2,1)
plt.plot(t, 2*s2)
plt.subplot(2,2,1)
plt.plot(t,4*s2)
plt.subplot(2,2,1)
plt.plot(t,10*s1)
#Aproveitando vamos definir os nomes dos eixos e do titulo do gráfico 
plt.xlabel("NOME DO EIXO X")
plt.ylabel("NOME DO EIXO Y")
plt.title("NOME DO TITULO")
# Out:
# C:\Users\alcid\Miniconda3\lib\site-packages\ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#
# C:\Users\alcid\Miniconda3\lib\site-packages\ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#
# ...

# %% [markdown]
# #  A partir de uma função definida

# %%
def f(x):
    return x**2 - 30

# %%
x1 = np.arange(-5, 5, 0.01)
ax = plt.subplot(1,1,1)
plt.plot(x1,f(x1))
plt.xticks(np.arange(min(x1), max(x1)+1, 1)) # quantidades de numeros no eixo x  ( valor inicial , final , subdivisões)
plt.yticks(np.arange(-50, 50, 10)) #uantidades de numeros no eixo y ( valor inicial , final , subdivisões)
plt.margins(0.05)  # zoom no grafico 
ax.spines['left'].set_position('center') # deslocando o eixo y para o centro da imagem 
ax.spines['bottom'].set_position('center')# deslocando o eixo x para o centro da imagem

# %% [markdown]
# Exemplo do Matplotlib de um plot dentro do outro

# %%
# Plot inside a plot
plt.style.use('seaborn-whitegrid')
fig, ax = plt.subplots(figsize=(10,6))
x = np.linspace(-0.50, 1., 1000)

# Outer Plot
ax.plot(x, x**3)
ax.plot(x, np.sin(x))
ax.set(xlim=(-0.5, 1.0), ylim=(-0.5,1.2))
fig.tight_layout()

# Inner Plot
inner_ax = fig.add_axes([0.2, 0.55, 0.35, 0.35]) # x, y, width, height
inner_ax.plot(x, x**2)
inner_ax.plot(x, np.sin(x))
inner_ax.set(title='Zoom In', xlim=(-.2, .2), ylim=(-.01, .02), 
             yticks = [-0.01, 0, 0.01, 0.02], xticks=[-0.1,0,.1])
ax.set_title("Plot inside a Plot", fontsize=20)
# Out:
# Text(0.5, 1, 'Plot inside a Plot')
